# %% [markdown]
# ![image.png](attachment:fc734435-c2ad-4a52-abde-79ce57a74287.png)

# %% [markdown]
# Abgabe per E-Mail an <a href="mailto:cedric.huwyler@fhnw.ch">cedric.huwyler@fhnw.ch</a>.

# %% [markdown]
# Bibliotheken einbinden (für Berechnungen ausschliesslich Numpy und Sympy erlaubt):

# %%
import numpy as np
import sympy as sp

# %% [markdown]
# ## Aufgabe 6 (11 Punkte)

# %% [markdown]
# Natural Language Processing (NLP) ist die Grundlage von Large Language Models wie ChatGPT und Co. Als typischerweise sehr früher Schritt wird dabei ein sogenanntes *Word Embedding* erstellt: Dabei bekommt jedes Wort einen Vektor aus $\mathbb{R}^n$ zugewiesen, welcher die Bedeutung des Worts und insbesondere die Beziehung des Worts zu anderen Wörtern codiert. Wie genau solche Vektoren gewählt werden, soll hier keine Rolle spielen.
#
# In dieser Aufgabe soll ein vorgegebenes Embedding auf seine Fähigkeiten hin untersucht werden, Ähnlichkeiten bezüglich Wortbedeutung abzubilden. Unten sind dazu folgende Daten enthalten:
#
# * Die 9 benutzten Wörter in einer Liste (`words`).
# * Ein Numpy-Array $X \in \mathbb{R}^{25 \times 9}$, das für jedes der 9 Wörter einen 25-dimensionalen Embedding-Vektor enthält.
#
# Für die Berechnungen ist ausschliesslich das Numpy-Paket erlaubt.

# %% [markdown]
# ### zu verwendende Daten:

# %%
words = ["computer", "laptop", "phone", "hello", "hey", "hi", "giraffe", "elephant", "monkey"]

X = np.array(
      [[ 0.64 ,  0.769,  0.457, -0.771, -0.012, -0.179, -1.379, -1.421, -0.96 ],
       [-0.02 ,  0.3  ,  0.158,  0.128,  0.658,  0.103, -0.983, -0.849, -0.379],
       [ 0.701,  0.976,  0.986,  0.331,  0.194, -0.108,  0.193,  0.188,  0.489],
       [-0.661, -0.571, -0.363,  0.005,  0.199, -0.072,  0.407,  0.561,  0.655],
       [ 1.172,  0.703,  0.453, -0.476, -0.694, -1.242, -0.138, -0.242,  0.214],
       [-0.589,  0.398, -0.053, -0.501, -0.219, -1.075, -0.281, -0.48 , -0.088],
       [ 0.259, -0.012,  0.963,  1.858,  1.51 ,  0.552,  0.591,  0.909,  1.284],
       [-0.815,  0.603,  0.15 ,  1.062,  1.29 ,  1.122, -1.193, -0.925, -0.111],
       [ 1.171,  1.37 ,  0.359, -0.565, -1.042, -0.521, -0.162,  0.325,  0.275],
       [ 1.141,  1.766,  1.459,  0.133,  0.25 ,  0.435,  0.198,  0.448,  0.423],
       [-0.154,  0.464, -0.422, -0.419, -0.492, -0.717,  0.786,  0.848,  0.362],
       [-0.114,  0.319,  0.379, -0.142, -0.156, -0.378,  0.283,  0.032,  0.396],
       [-3.841, -3.108, -4.279, -2.856, -3.192, -3.28 , -1.807, -2.384, -2.467],
       [-0.872, -1.01 , -1.052, -0.571, -1.005, -0.068, -0.595, -0.443, -0.961],
       [ 0.475, -0.062,  0.172, -0.134, -0.058, -0.712, -0.324, -0.585, -0.429],
       [ 1.154,  0.755,  1.046, -0.449, -0.315, -0.262,  0.104, -0.046,  0.006],
       [ 0.977,  0.848,  1.045,  0.486,  0.48 ,  0.647,  1.064,  0.87 ,  1.047],
       [ 1.111,  0.207, -0.646, -0.648, -0.479, -0.385, -0.223, -0.244, -0.52 ],
       [-0.146, -0.259, -0.671, -0.842, -1.073, -1.212,  0.055,  0.482,  0.381],
       [-0.52 ,  0.064, -0.494,  0.617,  0.53 ,  0.372,  0.274,  0.355,  0.721],
       [-0.522, -1.362,  0.316, -0.198,  0.805,  0.189, -0.142, -0.001,  0.226],
       [-0.923, -0.555, -1.182, -0.58 ,  0.042,  0.303,  1.18 ,  0.931,  0.683],
       [ 0.347,  0.82 ,  1.157, -0.659, -0.491, -0.29 , -0.117,  0.35 ,  0.518],
       [ 0.062,  1.004,  0.304,  0.439,  0.735,  0.851, -0.904, -1.28 , -0.73 ],
       [-0.574, -0.899, -1.477, -0.505, -0.112, -1.387,  0.335,  0.4  ,  0.629]]
)

# %% [markdown]
# ### a) (3 Punkte)
#
# Als Ähnlichkeitsmass benutzen wir die Cosine Similarity. Berechnen Sie die Cosine Similarities
#
# $$
# s_{ij} = \frac{\mathbf{x}_i \cdot \mathbf{x}_j}{|\mathbf{x}_i| \; |\mathbf{x}_i|}
# $$
#
# zwischen den Wörtern 'computer' und 'phone' und 'computer' und 'giraffe'. Welche der beiden Wörter sind sich ähnlicher? Entspricht das Ihren Erwartungen? Geben Sie die zwei Ähnlichkeiten schriftlich auf dem Papier gerundet auf zwei Stellen hinter dem Komma wieder.
#
# **Hinweis:** Die Spalten von $X$ repräsentieren die Wörter in `words` in entsprechender Reihenfolge.

# %%
# IHR CODE

# %% [markdown]
# ### b) (3 Punkte)
#
# Bestimmen Sie nun die Ähnlichkeitsmatrix $S \in \mathbb{R}^{9\times 9}$ zwischen allen Wörtern. Hier ist keine schriftliche Antwort erwartet.
#
#
# **Hinweis:** $S$ sollte Werte zwischen 0 und 1 und auf der Diagonalen sogar ausschliesslich Einsen enthalten.

# %%
# IHR CODE

# %% [markdown]
# ### c) (2 Punkte)
#
# Welche zwei Wörter sind sich am ähnlichsten? Welche zwei Wörter sind sich am wenigsten ähnlich? Geben Sie eine schriftliche Antwort.

# %%
# schriftliche Antwort auf Papier

# %% [markdown]
# ### d) (3 Punkte)
#
# Beschreiben Sie mit Formel(n) und wo nötig Worten, wie sie mit Hilfe einer Singulärwertzerlegung von $X^T$ eine Hauptkomponentenanalyse der in $X$ gespeicherten Embeddingvektoren durchführen können, mit dem Ziel, für die Repräsentation weniger als 25 Dimensionen zu verwenden. Was erwarten Sie qualitativ, wenn Sie die ersten zwei berechneten Hauptkomponenten in einem Scatterplot gegeneinander darstellen?

# %%
# schriftliche Antwort auf Papier

# %% [markdown]
# ## Aufgabe 7 (13 Punkte)
#
# Der Markt der Anbieter von Large Language Models bestehe aus 4 grossen Anbietern (wie OpenAI, Anthropic, Google, Facebook) und sei stark am Wachsen. Die Kundenzahlen der vier Anbieter seien durch den Vektor
#
# $$
# \mathbf{a} = \begin{pmatrix} a_1 \\ a_2 \\ a_3 \\ a_4 \end{pmatrix} \in \mathbb{R}^4
# $$
#
# beschrieben, wobei $a_1$, $a_2$, $a_3$ und $a_4$ die Kundenzahlen der einzelnen Anbieter bezeichnen. Jeden Monat kommen neue Kund:innen dazu und gewisse wechseln auch zu einem anderen Anbieter. Der Zuwachs und die Wechsel können mit einer Übergangsmatrix $T$ beschrieben werden:
#
# <br>
#
# \begin{eqnarray*}
# T = \begin{pmatrix} 1&0&0&0 \\ 0&1-t&t&t \\ 0&t&1-t&t \\ 0&t&t&1-t \end{pmatrix},
# \end{eqnarray*}
#
# <br>
#
# mit $0\leq t \leq 1$. Für jeden neuen Monat gilt also $\mathbf{a}_{n+1} = T \; \mathbf{a}_n$. Wir wollen untersuchen, ob nach hinreichend vielen Monaten ein Anbieter dominiert.

# %% [markdown]
# ### a) (2 Punkte)
#
# Definieren Sie die Übergangsmatrix $T$ für allgemeine $t$ mit sympy.

# %%
# IHR CODE

# %% [markdown]
# ### b) (4 Punkte)

# %% [markdown]
# Es sei $t=0.1$ und die Anfangskundenzahlen $\mathbf{a}_0 = (30,10,5,0)$. Welche(r) der vier Anbieter dominiert/dominieren nach 50 Monaten? (Geben Sie auf letztere Frage eine schriftlichen Antwort)

# %%
# IHR CODE

# %%
# schriftliche Antwort auf Papier

# %% [markdown]
# ### c) (4 Punkte)
#
# Nun wollen wir eine analytische Betrachtung des in b) beobachteten Sachverhalts durchführen.
# Bestimmen Sie dazu als erstes alle Eigenwerte und Eigenvektoren von $T$ ganz allgemein für $t$ und geben Sie sie schriftlich wieder. Welcher Eigenwert ist am grössten? Welches ist der Eigenvektor zum grössten Eigenwert?
#
# **Hinweis:** Erinnern Sie sich an $0 \leq t \leq 1$.

# %%
# IHR CODE

# %%
# schriftliche Antwort auf Papier

# %% [markdown]
# ### d) (3 Punkte)
#
# Da $T$ symmetrisch und damit diagonalisierbar ist, kann der Startvektor $\mathbf{a}_0$ nach Eigenvektoren von $T$ zerlegt werden:
#
# $\mathbf{a}_0 = \alpha_1 \mathbf{v}_1 + \alpha_2 \mathbf{v}_2 + \alpha_3 \mathbf{v}_3 + \alpha_4 \mathbf{v}_4$.
#
# Überlegen Sie sich, welcher Eigenvektor für $T^n \; \mathbf{a}_0$ für grosse $n$ dominiert und vergleichen Sie mit ihrem Resultat aus b). Hier reicht eine ausschliesslich schriftliche Antwort.

# %%
# schriftliche Antwort auf Papier
